# %% [markdown]
# Pandas

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.datasets import fetch_openml

# Load Boston housing prices dataset from UCI
boston = fetch_openml(name='boston', version=2)

# %%
type(boston)
# Out:
# sklearn.utils._bunch.Bunch

# %%
print(boston)
# Out:
# {'data':         CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622    3  222     18.7
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ...  ...      ...
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527   0.0  11.93    0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741   0.0  11.93    0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           B  LSTAT
# ...

# %%
# Convert to a Pandas DataFrame
boston_df = pd.DataFrame(boston.data, columns=boston.feature_names)
# boston_df['target'] = boston.target

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
diabetes_csv = pd.read_csv('diabetes.csv')
type(diabetes_csv)
# Out:
# pandas.core.frame.DataFrame

# %%
diabetes_csv.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
random_df = pd.DataFrame(np.random.rand(20,10))

# %%
random_df.shape
# Out:
# (20, 10)

# %%
random_df.info
# Out:
# <bound method DataFrame.info of            0         1         2         3         4         5         6  \
# 0   0.478433  0.711177  0.195883  0.384874  0.721393  0.271910  0.682476
# 1   0.526953  0.696094  0.709748  0.518567  0.948202  0.375134  0.139749
# 2   0.859198  0.868801  0.881482  0.747623  0.606676  0.961968  0.504610
# 3   0.644153  0.597098  0.236208  0.749220  0.405912  0.018013  0.470511
# 4   0.210918  0.726773  0.525036  0.181922  0.202689  0.970236  0.855127
# 5   0.036957  0.373312  0.843143  0.238679  0.239415  0.500617  0.422205
# 6   0.580099  0.249573  0.633931  0.132484  0.560905  0.703668  0.429247
# 7   0.688017  0.891172  0.192667  0.593673  0.618781  0.122929  0.748960
# 8   0.783483  0.926662  0.712139  0.405646  0.846472  0.909000  0.788046
# 9   0.277675  0.286322  0.322632  0.310525  0.334165  0.437835  0.350393
# 10  0.436346  0.938070  0.963214  0.291284  0.027226  0.050710  0.245896
# ...

# %%
boston_df.info
# Out:
# <bound method DataFrame.info of         CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622    3  222     18.7
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ...  ...      ...
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527   0.0  11.93    0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741   0.0  11.93    0  0.573  6.030  80.8  2.5050    1  273     21.0
#
# ...

# %%
boston_df.head
# Out:
# <bound method NDFrame.head of         CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622    3  222     18.7
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ...  ...      ...
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527   0.0  11.93    0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741   0.0  11.93    0  0.573  6.030  80.8  2.5050    1  273     21.0
#
# ...

# %%
diabetes_csv.value_counts('Outcome')
# Out:
# Outcome
# 0    500
# 1    268
# dtype: int64

# %% [markdown]
# This value counts gives no of things under a category
# Age 21 : theare are 432 people

# %%
diabetes_csv.value_counts('Age')
# Out:
# Age
# 22    72
# 21    63
# 25    48
# 24    46
# 23    38
# 28    35
# 26    33
# 27    32
# 29    29
# 31    24
# 41    22
# 30    21
# 37    19
# 42    18
# 33    17
# 38    16
# 36    16
# 32    16
# 45    15
# 34    14
# 40    13
# 43    13
# 46    13
# 39    12
# 35    10
# 52     8
# 44     8
# 50     8
# 51     8
# 58     7
# 54     6
# 47     6
# 53     5
# 60     5
# 49     5
# 57     5
# 48     5
# 66     4
# 62     4
# 63     4
# 55     4
# 59     3
# 56     3
# 65     3
# 67     3
# 61     2
# 69     2
# 64     1
# 68     1
# 70     1
# 72     1
# 81     1
# dtype: int64

# %%
# Outcome 0 is no diabetes
# Outcome 1 is are having diabetes

# %%
diabetes_csv.groupby('Outcome').mean()
# Out:
#          Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  109.980000      68.184000      19.664000   68.792000
# 1           4.865672  141.257463      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
diabetes_csv.count()
# count no of values
# Out:
# Pregnancies                 768
# Glucose                     768
# BloodPressure               768
# SkinThickness               768
# Insulin                     768
# BMI                         768
# DiabetesPedigreeFunction    768
# Age                         768
# Outcome                     768
# dtype: int64

# %%
# mean_value = column wise
#min value in each of the col
diabetes_csv.min()
# Out:
# Pregnancies                  0.000
# Glucose                      0.000
# BloodPressure                0.000
# SkinThickness                0.000
# Insulin                      0.000
# BMI                          0.000
# DiabetesPedigreeFunction     0.078
# Age                         21.000
# Outcome                      0.000
# dtype: float64

# %%
diabetes_csv.max()
# Out:
# Pregnancies                  17.00
# Glucose                     199.00
# BloodPressure               122.00
# SkinThickness                99.00
# Insulin                     846.00
# BMI                          67.10
# DiabetesPedigreeFunction      2.42
# Age                          81.00
# Outcome                       1.00
# dtype: float64

# %%
boston_df.max()
# Out:
# C:\Users\r555s\AppData\Local\Temp\ipykernel_3916\2329451156.py:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   boston_df.max()
# CRIM        88.9762
# ZN         100.0000
# INDUS       27.7400
# NOX          0.8710
# RM           8.7800
# AGE        100.0000
# DIS         12.1265
# RAD         24.0000
# TAX        711.0000
# PTRATIO     22.0000
# B          396.9000
# LSTAT       37.9700
# dtype: float64

# %%
#all statistical dataframes description in one touch
boston_df.describe()
# Out:
#              CRIM          ZN       INDUS         NOX          RM         AGE  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.554695    6.284634   68.574901
# std      8.601545   23.322453    6.860353    0.115878    0.702617   28.148861
# min      0.006320    0.000000    0.460000    0.385000    3.561000    2.900000
# 25%      0.082045    0.000000    5.190000    0.449000    5.885500   45.025000
# 50%      0.256510    0.000000    9.690000    0.538000    6.208500   77.500000
# 75%      3.677083   12.500000   18.100000    0.624000    6.623500   94.075000
# max     88.976200  100.000000   27.740000    0.871000    8.780000  100.000000
#
#               DIS         RAD         TAX     PTRATIO           B       LSTAT
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.795043    9.549407  408.237154   18.455534  356.674032   12.653063
# ...

# %%
diabetes_csv.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#Manipulating a DataFrame

# %%
boston_df.head()
# Out:
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT
# 0  396.90   4.98
# 1  396.90   9.14
# 2  392.83   4.03
# 3  394.63   2.94
# 4  396.90   5.33

# %%
# drop function
boston_df.drop(index=0 , axis=0)
# index - row removing number
# if u wanna remove the row axis =0 ; col axis = 1
# Out:
#         CRIM   ZN  INDUS CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 1    0.02731  0.0   7.07    0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2    0.02729  0.0   7.07    0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3    0.03237  0.0   2.18    0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4    0.06905  0.0   2.18    0  0.458  7.147  54.2  6.0622    3  222     18.7
# 5    0.02985  0.0   2.18    0  0.458  6.430  58.7  6.0622    3  222     18.7
# ..       ...  ...    ...  ...    ...    ...   ...     ...  ...  ...      ...
# 501  0.06263  0.0  11.93    0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93    0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93    0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93    0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93    0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           B  LSTAT
# 1    396.90   9.14
# ...

# %%
boston_df.drop(columns='ZN' , axis=1)
# Out:
#         CRIM  INDUS CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0    0.00632   2.31    0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1    0.02731   7.07    0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2    0.02729   7.07    0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3    0.03237   2.18    0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4    0.06905   2.18    0  0.458  7.147  54.2  6.0622    3  222     18.7
# ..       ...    ...  ...    ...    ...   ...     ...  ...  ...      ...
# 501  0.06263  11.93    0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  11.93    0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  11.93    0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  11.93    0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  11.93    0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           B  LSTAT
# 0    396.90   4.98
# 1    396.90   9.14
# 2    392.83   4.03
# 3    394.63   2.94
# ...

# %%
boston_df.iloc[2]
# All values entered in a single row
# Out:
# CRIM       0.02729
# ZN             0.0
# INDUS         7.07
# CHAS             0
# NOX          0.469
# RM           7.185
# AGE           61.1
# DIS         4.9671
# RAD              2
# TAX            242
# PTRATIO       17.8
# B           392.83
# LSTAT         4.03
# Name: 2, dtype: object

# %%
# # locate a column

print(boston_df.iloc[:,0])# first col
print(boston_df.iloc[:1]) # second col
print(boston_df.iloc[:,-1]) # last col
# Out:
# 0      0.00632
# 1      0.02731
# 2      0.02729
# 3      0.03237
# 4      0.06905
#         ...
# 501    0.06263
# 502    0.04527
# 503    0.06076
# 504    0.10959
# 505    0.04741
# Name: CRIM, Length: 506, dtype: float64
#       CRIM    ZN  INDUS CHAS    NOX     RM   AGE   DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31    0  0.538  6.575  65.2  4.09    1  296     15.3
#
#        B  LSTAT
# 0  396.9   4.98
# 0      4.98
# 1      9.14
# 2      4.03
# 3      2.94
# 4      5.33
#        ...
# 501    9.67
# 502    9.08
# 503    5.64
# 504    6.48
# 505    7.88
# Name: LSTAT, Length: 506, dtype: float64

# %% [markdown]
# Correlation finds a relation amongst the cols

# %%
diabetes_csv.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
boston_df.corr()
# Out:
# C:\Users\r555s\AppData\Local\Temp\ipykernel_3916\535603391.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   boston_df.corr()
#              CRIM        ZN     INDUS       NOX        RM       AGE       DIS  \
# CRIM     1.000000 -0.200469  0.406583  0.420972 -0.219247  0.352734 -0.379670
# ZN      -0.200469  1.000000 -0.533828 -0.516604  0.311991 -0.569537  0.664408
# INDUS    0.406583 -0.533828  1.000000  0.763651 -0.391676  0.644779 -0.708027
# NOX      0.420972 -0.516604  0.763651  1.000000 -0.302188  0.731470 -0.769230
# RM      -0.219247  0.311991 -0.391676 -0.302188  1.000000 -0.240265  0.205246
# AGE      0.352734 -0.569537  0.644779  0.731470 -0.240265  1.000000 -0.747881
# DIS     -0.379670  0.664408 -0.708027 -0.769230  0.205246 -0.747881  1.000000
# ...
